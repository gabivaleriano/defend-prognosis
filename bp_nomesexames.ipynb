# %% [markdown]
# Unificação de nomes dos exames para estudo de gravidade.
#
# Alguns exames possuem nomes diferentes, apesar de representarem a mesma medida.
# A identificação dos nomes que poderiam ser unificados foi feita com o auxílio de um especialista.
#
# Autoras: Maria Gabriela Valeriano e Ana Carolina Lorena
#
# Dados disponíveis em: https://repositoriodatasharingfapesp.uspdigital.usp.br/

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#le o arquivo bp exames
exames <- read.csv("bpsp_exames_01.csv", sep="|")

# %%
#renomeia as colunas
names(exames) <- c('id', 'id.atendimento', 'data.exame', 'clínica', 'exame', 'analito', 'resultado', 'unidade', 'referência')

# %%
#seleciona as colunas exame e analito
nomes <- exames %>% select(exame,analito)

# %%
#espaços e caracteres especiais
nomes <- data.frame(lapply(nomes, function(x) {gsub("[()]", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("%", "percentual", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("[[:punct:]]", "", x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("\\s+", " ", x)}))
nomes <- data.frame(lapply(nomes, function(x) {tolower(x)}))

#unifica nomes dos exames
nomes <- data.frame(lapply(nomes, function(x) {gsub("acido lactico para protocolo de sepse sangue arterial", "acido lactico lactato sangue total arterial", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("acido lactico para protocolo de sepse sangue venoso", "Acido lactico lactato sangue total venoso", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("acido urico urina amostra isolada", "acido urico urina", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("acido urico urina de 24 horas", "acido urico urina", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("acido urico urina isolada", "acido urico urina", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("antigeno prostatico especifico psa livre soro", "antigeno prostatico especifico psa total soro", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram urina jato medio", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram urina sem especificacao de jato", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram varios materiais", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram esperma", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram para gardnerella vaginalis varios materiais", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico gram urgente varios materiais", "bacterioscopico gram", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "bacterioscopico gram vaginal", "bacterioscopico gram", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("borrelia burgdorferi anticorpos totais soro", "borrelia burgdorferi pesquisa de anticorpos por imunoblot soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("borrelia burgdorferi doenca de lyme igg", "borrelia burgdorferi doenca de lyme", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("calcio ionico sangue total arterial", "calcio ionico", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("calcio ionico sangue total venoso", "calcio ionico", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("cloro sangue total arterial", "cloro sangue", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cloro sangue total venoso", "cloro sangue", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("cortisol amostra das 16 horas soro", "cortisol amostra das 8 horas soro", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("dengue anticorpo igg prova rapida soro", "dengue anticorpos igg soro", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("dengue anticorpo igm prova rapida soro", "dengue anticorpos igm soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrograma sangue total", "hemograma", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("estradiol  e2, soro", "estradio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("estradiol ultrassensivel soro", "estradiol", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("fator anti x ativado antixa para heparina de baixo peso molecular plasma", "fator anti x ativado anti-xa para heparina", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("fator anti x ativado antixa para heparina nao fracionada plasma", "fator anti x ativado anti-xa para heparina", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose plasma", "glicose", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose sangue venoso", "glicose", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose sangue arterial", "glicose", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose pos prandial 2 horas plasma", "glicose", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose pos prandial", "glicose", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose sangue", "glicose", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("gordura fecal pesquisa fezes", "gordura dosagem fezes", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("gordura por micrometodo fezes", "gordura dosagem fezes", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("hematocrito ht sangue arterial", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hematocrito ht sangue venoso", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hematocrito ht sangue total", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("leucograma sangue total", "hemograma", x)}))


nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura aerobia banco de sangue", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura anaerobia banco de sangue", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura aerobios", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura anaerobios", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura p fungos identificacao rapida por malditof varios materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura p fungos identificacao rapida por malditof varios materiais", "hemocultura", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("resultado integrar com ccih hospitais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("resultado parcial", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura p fungos identificacao rapida por malditof varios materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial hemocultura p fungos identificacao rapida por malditof", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura 1 amostra", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial hemocultura 1 amostra", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial hemocultura", "hemocultura", x)}))


nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura p fungos identificacao rapida por maldi-tof varios materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemocultura para micobacterias automatizada varios materiais", "hemocultura", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("hemoglobina hb sangue arterial", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemoglobina hb sangue venoso", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemoglobina hb sangue total", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemograma completo sangue total", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemograma total com contagem de bastonetes sangue total", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemograma prequimioterapia sangue total", "hemograma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemograma protocolo de neutropenia febril", "hemograma", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("hepatite b anticorpos hbe soro", "hepatite b antigeno hbe soro", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("hepatite b antigeno de superficie hbsag soro", "hepatite b antigeno de superficie hbsag urgente soro", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("hiv 1 e 2 anticorpos teste rapido soro", "hiv i e ii  anticorpos totais soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hiv1hiv2 teste rapido", "hiv1hiv2", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("insulina pos prandial soro", "insulina soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("insulina livre soro", "insulina soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("insulina livre", "insulina", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("plaquetas contagem especial sangue total", "plaquetas contagem sangue total", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("potassio sangue total arterial", "potassio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("potassio sangue total venoso", "potassio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("potassio plasma", "potassio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("potassio sangue total", "potassio", x)}))


nomes <- data.frame(lapply(nomes, function(x) {gsub("proteinas totais e fracoes plasma", "proteinas totais plasma", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio sangue total arterial", "sodio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio sangue total venoso", "sodio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio plasma", "sodio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio sangue", "sodio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio sangue venoso", "sodio", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sodio venoso", "sodio", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("t3 triiodotironina soro", "t3", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "t3 reverso soro","t3", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "t3 reverso","t3", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "t3 livre soro","t3", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "t3 livre","t3", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub( "triiodotironina t3","t3", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("t4 tiroxina soro", "t4", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("tiroxina t4", "t4", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("t4 livre soro", "t4", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("t4 livre", "t4", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona livre soro", "testosterona", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona total soro", "testosterona", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona livre", "testosterona", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("trichomonas pesquisa secrecao vaginal", "trichomonas", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("trichomonas pesquisa urina primeiro jato", "trichomonas", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("ureia apos dialise soro", "ureia plasma", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("ureia posdialise", "ureia", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("vitamina d 25hidroxi soro", "125dihidroxi vitamina d vitamina d 125 dihidroxi soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("25 hidroxi vitamina d", "250h vitamina d total", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("vitamina d 125 dihidroxi", "25 hidroxi vitamina d", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("250h vitamina d total", "25 hidroxi vitamina d", x)}))

#cultura
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura aerobios varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura anaerobios varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura com sonicacao varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de urina apos massagem prostatica urina  posmassagem prostatica", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de vigilancia para bacilos gram negativos resistentes a carbapenemicos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de vigilancia para enterococcus resitente a vancomicina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura fungos varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura micobacterias baarbk varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para leptospira varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para micoplasma ureaplasma varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura quantitativa para aerobios varios materiais de trato respiratorio", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura escarro", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura fezes", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura fossa nasal varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura orofaringe", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para bordetella pertussis varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para çeptospira varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura secrecao de nasofaringe", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura secrecao uretral", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura staphylococcus aureus resistente a oxacilina varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura streptococcus betahemolitico do grupo b varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina jato final", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina jato medio", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina primeiro jato", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina sem especificacao de jato", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura vaginal", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de urina apos massagem prostatica urina posmassagem prostatica", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura de urina apos massagem prostatica", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologica celepit", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologica material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologicaleucocitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar apos homog nalcnaoh pesquisa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar exame direto pesquisa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico bacilos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico celulas epiteliais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico cocos gram positivos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico germes coraveis", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("coprocultura", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para aerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para anaerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para fungos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para micobacterias", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para micoplasma ureaplasma", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura quantitativa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura streptococcus beta hemolitico do grupo b varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("dismorfismo urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrocitos quantitativo urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("leucocitos quantitativo urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("outros urina i", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial bacilos gramnegativos resistente a carbapenemicos cultura", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura enterococcus sp resistente a vancomicina varios mat", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para aerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para anaerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para fungos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para micobacterias", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura quantitativa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial urocultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("tricomonas pesquisa na secrecao uretral", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urocultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologica celepit", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologica material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiologicaleucocitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar apos homog nalcnaoh pesquisa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar exame direto pesquisa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("baar material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacilos gramnegativos resistente a carbapenemicos cultura varios mat", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico bacilos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico celulas epiteliais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico cocos gram positivos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico germes coraveis", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopico material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("celulas epiteliais urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("celulas epiteliais urina 1j", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("coprocultura", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura enterococcus sp resistente a vancomicina varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para aerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para anaerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para fungos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para micobacterias", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para micoplasma ureaplasma", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura quantitativa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura streptococcus beta hemolitico do grupo b varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura varios materiais", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("dismorfismo urina", "cultura", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrocitos quantitativo urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrocitos quantitativo urina 1j", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("leucocitos quantitativo urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("leucocitos quantitativo urina 1j", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("observacao", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("outros urina i", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial bacilos gramnegativos resistente a carbapenemicos cultura", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura de urina apos massagem prostatica", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura enterococcus sp resistente a vancomicina varios mat", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para aerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para anaerobios", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para fungos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura para micobacterias", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial cultura quantitativa", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("parcial urocultura automatizada", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("tricomonas pesquisa na secrecao uretral", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("tricomonas secrecao vaginal", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("tricomonas urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urocultura automatizada", "cultura", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("aspartato aminotransferase transaminase glutamico oxalacetica tgo plasma", "tgo", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("transaminase glutamico piruvica tgp plasma", "tpg", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("urina i jato final", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina i jato medio", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina i primeiro jato", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina colhida por sonda vesical de alivio", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina sem especificacao de jato", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("1j", "", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("\\s+", " ", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))

# %%
exames %>% select(-c(exame, analito)) -> exames
exames %>% cbind(nomes) -> exames

exames %>% mutate(exameEanalito = (str_c(exame, "/", analito))) -> exames

exames <- data.frame(lapply(exames, function(x) {gsub("cultura/observacao", "cultura/cultura", x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("cultura/trichomonas", "cultura/cultura", x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("insulina soro/glicose", "glicose/glicose", x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("insulina soro/glicose pos prandial", "glicose/glicose", x)}))


exames %>% select(exameEanalito) %>% unique %>% write_csv("nomesexbp.csv")
exames %>% write_csv("bpsp_exames_01_nomesproc.csv")
