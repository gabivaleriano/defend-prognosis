# %% [markdown]
# Unificação de nomes dos exames para estudo de gravidade.
#
# Alguns exames possuem nomes diferentes, apesar de representarem a mesma medida.
# A identificação dos nomes que poderiam ser unificados foi feita com o auxílio de um especialista.
#
# Autoras: Maria Gabriela Valeriano e Ana Carolina Lorena
#
# Dados disponíveis em: https://repositoriodatasharingfapesp.uspdigital.usp.br/

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#le o arquivo Sírio exames
exames <- read.csv("HSL_Exames_4.csv", sep="|")
# Out:
# [1] "ID_PACIENTE"         "ID_ATENDIMENTO"      "DT_COLETA"
# [4] "DE_ORIGEM"           "DE_EXAME"            "DE_ANALITO"
# [7] "DE_RESULTADO"        "CD_UNIDADE"          "DE_VALOR_REFERENCIA"

# %%
#renomeia as colunas
names(exames) <- c('id', 'id.atendimento', 'data.exame', 'clínica', 'exame', 'analito', 'resultado', 'unidade', 'referência')

# %%
nomes <- exames %>% select(exame,analito)

# %%
#espaços e caracteres especiais
nomes <- data.frame(lapply(nomes, function(x) {gsub("[()]", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("%", "percentual", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("[[:punct:]]", "", x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("1º", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("\\s+", " ", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))

#unifica nomes exames
nomes <- data.frame(lapply(nomes, function(x) {gsub("Acetilcolina Anticorpo Anti", "Acetilcolina Anticorpos Bloqueadores do Receptor soro", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Beta 2 glicoproteina 1 autoanticorpos", "BETA2GLICOPROTEINA 1 AUTOANTICORPO IGM SORO", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bk Micobact Cultura Medula Ossea", "Bk Micobactérias Cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Creatino Fosfoquinase Cpk", "Creatinofosfoquinase CpkCk", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Fator V Leiden Pesquisa Da Mutação G 2010A Protrombina", "Fator V Atividade", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Gama Gt", "Gama Glutamil Transferase Ggt", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Mitocondria Cortes Rim Rato ANTCO", "Mitocondria Fração M2 Anticorpo", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Prograf Fk 506 Tacrolimus Dosagem", "Prograf Em Tempos", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Protoparasitologico 1 Amostra", "Protoparasitológico", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Tempo E Ativid Protrombina Tp", "Tempo TrombParcial Ativada", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Vitamina D 25 hidroxi Vitamina D3 Soro", "Vitamina D 125 Dihidroxi", x)}))

#hemocultura
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para aeróbios por malditof vários materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para anaeróbios por malditof vários materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para fungos por malditof vários materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para Aeróbios Vários Materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para Anaeróbios Vários Materiais", "hemocultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para Fungos Varios Materiais", "hemocultura", x)})  )
nomes <- data.frame(lapply(nomes, function(x) {gsub("Hemocultura para Micobactérias automatizada Vários Materiais", "hemocultura", x)})  )
      
#bk
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bk Baar Cultura Lavado Bronquico", "Bk Baar", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bk Baar Pesquisa  Escarro", "Bk Baar", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bk Baar Pesquisa Vários Materiais", "Bk Baar", x)}))

#cultura
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Sec Uretral Masculina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada  Orofaringe", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada 1 Amostra  geral", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada Geral", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada de Escarro", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada Vaginal", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Automatizada Nasal", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura com Sonicação vários materiais", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura de urina sem especificação de jato para Unidades", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Quantitativa Sec Traqueal E Lavado", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura liquor Fleury", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura para bacilo gram negativo multirresistente varios materiais", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura secreção de nasofaringe", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Staphylococcus aureus resistente a oxacilina varios materiais", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("Cultura Streptococcus Beta Hemolítico do Grupo B Vários Materiais", "cultura", x)}))

#bacterioscopia
#nomes <- data.frame(lapply(nomes, function(x) {gsub("bacteriologgram e culturas líquor fleury", "bacterioscopia", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" Escarro", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("  01 amostra", "", x)}))                     
nomes <- data.frame(lapply(nomes, function(x) {gsub(" Nasofaringe", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" Urina primeiro jato", "", x)}))    
nomes <- data.frame(lapply(nomes, function(x) {gsub(" urina sem especificação de jato", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bacterioscópico líquor", "bacterioscopia", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bacterioscópico Esperma", "bacterioscopia", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bacterioscopico urina jato medio", "bacterioscopia", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bacterioscópico Vaginal Vários Materiais", "bacterioscopia", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Bacterioscópico", "Bacterioscopia", x)}))
                     
#cálcio ionizado
nomes <- data.frame(lapply(nomes, function(x) {gsub(" POS FILTRO SANGUE VENOSO", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" pós filtro plasma", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("Ionizável", 'ionizado', x)}))
                     
#vírgulas, minúsculo e pontuação
nomes <- data.frame(lapply(nomes, function(x) {tolower(x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacteriologgram e culturas  líquor fleury", "bacterioscopia", x)}))

#cultura analitos
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada amostra geral", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada amostra geral parcial", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiológica célepit", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiológica material", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("anal qualidamostra microbiológicaleucócitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada de", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada 3ª amostra", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada 3ª amostra parcial", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada nasal", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada orofaringe", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos c mobiluncusscore", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos de doderlein", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram negativo mob", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram negativos", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram positivos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram variáveis", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia células epiteliais", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia cocobacilos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia cocos gram positivos", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia eritrócitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia índice de nugent", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia leucócitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia leveduras", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopiabacilos de doderlein score", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopiabacilos gram variáveisscore", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura automatizada vaginal", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura com sonicação", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura com sonicação parcial", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de urina", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("células epiteliais urina", "cultura", x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura de urina parcial", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("observação", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("outros urina i", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para bacilo gram negativo", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para bacilo gram parcial", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para bordetella pertussis", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura para trichomonas", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura quantitativa","cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura quantitativa parcial", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram positivos", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia bacilos gram variáveis", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia células epiteliais", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia cocobacilos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia cocos gram positivos", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia diplococos gram negativos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia eritrócitos", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia leucócitos", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia leveduras", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia material", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura secreção de nasofaringe", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura staphylococcus aureus", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura staphylococcus aureus parcial", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura streptococcus beta hemolítico", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("anaerobios cultura", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura anaerobios parcial", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura parcial", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina terceiro jato parcial", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura urina terceiro jato", "cultura", x)}))

#urina cultura
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina cultura 1º jato", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina cultura jato final", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina cultura jato médio", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina cultura jato", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("bacterioscopia germes coráveis", "cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("dismorfismo urina 1j", "cultura", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("leucócitos quantitativo urina 1j", "cultura", x)}))   

#urgência
nomes <- data.frame(lapply(nomes, function(x) {gsub(" kit urg", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" urgência", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" urgente", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" urg", "", x)}))  

#glicemia                    
nomes <- data.frame(lapply(nomes, function(x) {gsub(" de jejum", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" pós prandial", '', x)})) 
nomes <- data.frame(lapply(nomes, function(x) {gsub(" pósprandial", '', x)}))                    
nomes <- data.frame(lapply(nomes, function(x) {gsub(" para coleta domiciliar", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicose arterial", "glicose", x)})) 
nomes <- data.frame(lapply(nomes, function(x) {gsub(" coleta domiciliar", "", x)})) 
nomes <- data.frame(lapply(nomes, function(x) {gsub("glicemia", "glicose", x)})) 

#insulina
nomes <- data.frame(lapply(nomes, function(x) {gsub(" combinada com glicose", '', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("homair", 'insulina', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("insulina/imc índice de massa corporal", 'insulina/insulina', x)}))
  
#plaquetas
nomes <- data.frame(lapply(nomes, function(x) {gsub(" agregacao", '', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq lag time colágeno 10 microgml", 'plaquetas', x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq lag time colágeno 50 microgml", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq máx ác aracdônico 500 microgml", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq máxima adrenalina 20 microm", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq máxima colágeno 10 microgml", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq máxima ristocetina 05ml", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaq máxima ristocetina 12ml", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaquetária máxima adp 100 microm", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("agreg plaquetária máxima adp 25 microm", 'plaquetas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("número de plaquetas no prp após diluição", 'plaquetas', x)}))

#correção/ajuste de palavras  
nomes <- data.frame(lapply(nomes, function(x) {gsub(" fracoes", " frações", x)})) #bilirrubinas   
nomes <- data.frame(lapply(nomes, function(x) {gsub("fracao", "fração", x)})) #bilirrubinas   
nomes <- data.frame(lapply(nomes, function(x) {gsub("ldh", 'dhll', x)})) #desidrogenase  
nomes <- data.frame(lapply(nomes, function(x) {gsub("metanefrinas", 'metanefrina', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("citrulinado", 'c', x)})) #peptideo
nomes <- data.frame(lapply(nomes, function(x) {gsub("urico", 'úrico', x)})) #peptideo
                     
#remoção de palavras
nomes <- data.frame(lapply(nomes, function(x) {gsub(" soro", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" total e frações", "", x)})) #o exame colesterol total e frações tem analitos difernetes
nomes <- data.frame(lapply(nomes, function(x) {gsub(" sangue total", "", x)}))         
nomes <- data.frame(lapply(nomes, function(x) {gsub(" sangue", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" total", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" vários materiais", '', x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" contagem", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" especial", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" teste rápido", "", x)})) #dengue
nomes <- data.frame(lapply(nomes, function(x) {gsub(" livre", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" plasma", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" prova rápida", "", x)})) #creatinina
nomes <- data.frame(lapply(nomes, function(x) {gsub(" soso", '', x)})) #estradiol  
nomes <- data.frame(lapply(nomes, function(x) {gsub(" pediátrico", '', x)})) #hormonio luteinizante
nomes <- data.frame(lapply(nomes, function(x) {gsub(" mg", '', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("magnesio", 'magnésio', x)})) 
nomes <- data.frame(lapply(nomes, function(x) {gsub(" k", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" por imunoturbidimetria", '', x)})) #proteina c reativa
nomes <- data.frame(lapply(nomes, function(x) {gsub(" tt", '', x)})) # trombina
nomes <- data.frame(lapply(nomes, function(x) {gsub(" dr3", "", x)})) #sensibilidade para fungos
nomes <- data.frame(lapply(nomes, function(x) {gsub(" biodisponível", "", x)})) #testosterona
nomes <- data.frame(lapply(nomes, function(x) {gsub("triglicerídios tg", 'triglicérides', x)})) #triglicerideos
nomes <- data.frame(lapply(nomes, function(x) {gsub(" t ultrassensível", '', x)}))  #troponina
nomes <- data.frame(lapply(nomes, function(x) {gsub(" para hospitais", "", x)})) #protombina   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" tt", "", x)})) #trombina   
nomes <- data.frame(lapply(nomes, function(x) {gsub("calcio", 'cálcio', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("catecolaminas", 'catecolamina', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("acido", 'ácido', x)})) #ácido urico
nomes <- data.frame(lapply(nomes, function(x) {gsub("potassio", 'potássio', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("proteínas", 'proteinas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("e frações", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("t4l", 't4', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" 1j", '', x)}))

#proteinas
nomes <- data.frame(lapply(nomes, function(x) {gsub(" totais", "", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" ptf", "", x)}))      
nomes <- data.frame(lapply(nomes, function(x) {gsub("proteínas", 'proteinas', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("e frações", '', x)}))
                     
#tireoglobulina                     
nomes <- data.frame(lapply(nomes, function(x) {gsub(" após estímulo de tsh", '', x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub(" serica", '', x)}))                      
                     
#t3 e t4                 
nomes <- data.frame(lapply(nomes, function(x) {gsub(" reverso", '', x)}))                         
nomes <- data.frame(lapply(nomes, function(x) {gsub(" tri iodotironina", '', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub(" tetraiodotironina", '', x)}))           

#gasometria
nomes <- data.frame(lapply(nomes, function(x) {gsub("gasometria arterial", 'gasometria', x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub("gasometria venosa", 'gasometria', x)}))    
                     
#hemograma                    
nomes <- data.frame(lapply(nomes, function(x) {gsub("hbht", 'hemograma', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemograma automatizado préqt", 'hemograma', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrograma eritrócitos hemoglobina hematócrito", 'hemograma', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("eritrograma", 'hemograma', x)}))                     
nomes <- data.frame(lapply(nomes, function(x) {gsub("hematócrito", 'hemograma', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hematocrito", 'hemograma', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("hemoglobina", 'hemograma', x)}))

#colesterol - nomes dos analitos são diferentes
nomes <- data.frame(lapply(nomes, function(x) {gsub(" fração hdl", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" fração ldl", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" nãohdl", '', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" fração vldl", '', x)}))

#proteínas                     
nomes <- data.frame(lapply(nomes, function(x) {gsub(" totais e frações", "", x)}))                     
nomes <- data.frame(lapply(nomes, function(x) {gsub(" PTF", "", x)}))                          
                     
#urinário
nomes <- data.frame(lapply(nomes, function(x) {gsub("urin amostisolada", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("amostra isolada urina", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urinaria", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urinária", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("amostra isolada urina", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina amostra isolada", 'urinario', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub('urinário', "urinario", x)}))  
nomes <- data.frame(lapply(nomes, function(x) {gsub('globulinas', "globulina", x)})) 

nomes <- data.frame(lapply(nomes, function(x) {gsub("\\s+", " ", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" $", "", x)}))
 

nomes <- data.frame(lapply(nomes, function(x) {gsub("vitamina d 25 hidroxi por lcms", "vitamina d 125 dihidroxi", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("testolms testosterona por lcmsms", "testosterona por lcmsms", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("sódio urina amostra isolada", "sódio urinario", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub(" isolada", "", x)}))


#urina
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina tipo 1 jato medio", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina tipo i 1 jato", "urina tipo 1", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina tipo i jato final", "urina tipo 1", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("urina tipo i jato medio", "urina tipo 1", x)}))   

#trichomonas
nomes <- data.frame(lapply(nomes, function(x) {gsub("trichomonas pesquisa secreção uretral", "trichomonas pesquisa", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("trichomonas pesquisa secreção vaginal", "trichomonas pesquisa", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("trichomonas pesquisa urina primeiro jato", "trichomonas pesquisa", x)}))

#fungos
nomes <- data.frame(lapply(nomes, function(x) {gsub("fungos cultura 1 amostra", "fungos cultura", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("fungos pesquisa 1ª amostra", "fungos cultura", x)}))

#tgo/tgp
nomes <- data.frame(lapply(nomes, function(x) {gsub("transaminase oxalacética tgo", "tgo", x)}))   
nomes <- data.frame(lapply(nomes, function(x) {gsub("transaminase pirúvica tgp", "tgp", x)}))

#bk
nomes <- data.frame(lapply(nomes, function(x) {gsub("micobact ", "micobactérias ", x)}))

#amilase
nomes <- data.frame(lapply(nomes, function(x) {gsub("183", "amilase", x)}))

#cloro
nomes <- data.frame(lapply(nomes, function(x) {gsub("cloro arterial", "cloro", x)}))

# %%
exames %>% select(-c(exame,analito)) -> exames
exames %>% cbind(nomes) -> exames
#cria mais uma coluna unindo exameEanalito
exames %>% mutate(exameEanalito = (str_c(exame, "/", analito))) -> exames

# %%
exames %>% select(exameEanalito) -> nomes

# %%
nomes <- data.frame(lapply(nomes, function(x) {tolower(x)}))

#analitos
nomes <- data.frame(lapply(nomes, function(x) {gsub("cálcio ionizado/cálcio ionizado pós filtro", 'cálcio ionizado/cálcio ionizado', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cálcio ionizado/cálcio ionizadoarte", 'cálcio ionizado/cálcio ionizado', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cálcio ionizado/cálcio ionizavel", 'cálcio ionizado/cálcio ionizado', x)}))


nomes <- data.frame(lapply(nomes, function(x) {gsub(" leiden", "", x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("normetnefrina", 'normetanefrina', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("antimitocondrial fração m2 anticorpo", 'antimitocondrial anticorpo', x)}))

exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura fungos", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura/hemocultura fungos parcial", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura/hemocultura para aeróbios", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura/hemocultura para aeróbios parcial", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura para anaeróbios", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura para anaeróbios parcial", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura/hemocultura parcials", 'hemocultura', x)}))
exames <- data.frame(lapply(exames, function(x) {gsub("hemocultura/hemocultura resultado parcial", 'hemocultura', x)}))

#testosterona
nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona/observação", 'testosterona/testosterona', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona/shbg", 'testosterona/testosterona', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("testosterona por lcmsms/testosterona massa", 'testosterona por lcmsms/testosterona', x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura/resultado integrar com ccih hospitais", 'cultura/cultura', x)}))
nomes <- data.frame(lapply(nomes, function(x) {gsub("cultura/resultado parcial", 'cultura/cultura', x)}))

#prograf
nomes <- data.frame(lapply(nomes, function(x) {gsub("prograf em tempos/tacrolimus elisa", 'prograf em tempos/tacrolimus', x)}))

nomes <- data.frame(lapply(nomes, function(x) {gsub("teste de sensibilidade para fungos/resultado integrar com ccih hospitais", 'teste de sensibilidade para fungos/teste de sensibilidade para fungos', x)}))

# %%
exames %>% select(-c(exameEanalito)) -> exames
exames %>% cbind(nomes) -> exames
exames %>% select(exameEanalito) %>% unique %>% write_csv("nomesexjunho.csv")
exames %>% write_csv("HSL_Exames_4_nomesproc.csv")
