# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.1     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#read the original file
tests <- read.csv("HSL_Exames_4.csv", sep="|")

# %%
names(tests) <- c('id', 'id_attendance', 'test_date', 'place', 'test', 'analyte', 'result', 'measurement_unit', 'normal_value')

# %%
labels <- tests %>% select(test,analyte)

# %%
labels <- data.frame(lapply(labels, function(x) {gsub("[()]", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("%", "percentual", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("[[:punct:]]", "", x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("1º", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("\\s+", " ", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("Acetilcolina Anticorpo Anti", "Acetilcolina Anticorpos Bloqueadores do Receptor soro", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Beta 2 glicoproteina 1 autoanticorpos", "BETA2GLICOPROTEINA 1 AUTOANTICORPO IGM SORO", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bk Micobact Cultura Medula Ossea", "Bk Micobactérias Cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Creatino Fosfoquinase Cpk", "Creatinofosfoquinase CpkCk", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Fator V Leiden Pesquisa Da Mutação G 2010A Protrombina", "Fator V Atividade", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Gama Gt", "Gama Glutamil Transferase Ggt", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Mitocondria Cortes Rim Rato ANTCO", "Mitocondria Fração M2 Anticorpo", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Prograf Fk 506 Tacrolimus Dosagem", "Prograf Em Tempos", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Protoparasitologico 1 Amostra", "Protoparasitológico", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Tempo E Ativid Protrombina Tp", "Tempo TrombParcial Ativada", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Tempo de tromboplastina parcial ativada teste rápido para Hospitais plasma", "Tempo TrombParcial Ativada", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Vitamina D 25 hidroxi Vitamina D3 Soro", "Vitamina D 125 Dihidroxi", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para aeróbios por malditof vários materiais", "hemocultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para anaeróbios por malditof vários materiais", "hemocultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para fungos por malditof vários materiais", "hemocultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para Aeróbios Vários Materiais", "hemocultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para Anaeróbios Vários Materiais", "hemocultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para Fungos Varios Materiais", "hemocultura", x)})  )
labels <- data.frame(lapply(labels, function(x) {gsub("Hemocultura para Micobactérias automatizada Vários Materiais", "hemocultura", x)})  )
      
labels <- data.frame(lapply(labels, function(x) {gsub("Bk Baar Cultura Lavado Bronquico", "Bk Baar", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bk Baar Pesquisa  Escarro", "Bk Baar", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bk Baar Pesquisa Vários Materiais", "Bk Baar", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Sec Uretral Masculina", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada  Orofaringe", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada 1 Amostra  geral", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada Geral", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada de Escarro", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada Vaginal", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Automatizada Nasal", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura com Sonicação vários materiais", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura de urina sem especificação de jato para Unidades", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Quantitativa Sec Traqueal E Lavado", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura liquor Fleury", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura para bacilo gram negativo multirresistente varios materiais", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura secreção de nasofaringe", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Staphylococcus aureus resistente a oxacilina varios materiais", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("Cultura Streptococcus Beta Hemolítico do Grupo B Vários Materiais", "cultura", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub(" Escarro", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" 01 amostra", "", x)}))                     
labels <- data.frame(lapply(labels, function(x) {gsub(" Nasofaringe", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" Urina primeiro jato", "", x)}))    
labels <- data.frame(lapply(labels, function(x) {gsub(" urina sem especificação de jato", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bacterioscópico líquor", "bacterioscopia", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bacterioscópico Esperma", "bacterioscopia", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bacterioscopico urina jato medio", "bacterioscopia", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bacterioscópico Vaginal Vários Materiais", "bacterioscopia", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Bacterioscópico", "Bacterioscopia", x)}))
                     
labels <- data.frame(lapply(labels, function(x) {gsub(" POS FILTRO SANGUE VENOSO", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" pós filtro plasma", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("Ionizável", 'ionizado', x)}))

labels <- data.frame(lapply(labels, function(x) {tolower(x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacteriologgram e culturas  líquor fleury", "bacterioscopia", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada amostra geral", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada amostra geral parcial", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("anal qualidamostra microbiológica célepit", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("anal qualidamostra microbiológica material", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("anal qualidamostra microbiológicaleucócitos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada de", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada 3ª amostra", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada 3ª amostra parcial", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada nasal", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada orofaringe", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos c mobiluncusscore", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos de doderlein", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram negativo mob", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram negativos", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram positivos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram variáveis", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia células epiteliais", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia cocobacilos gram negativos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia cocos gram positivos", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia eritrócitos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia índice de nugent", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia leucócitos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia leveduras", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia material", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopiabacilos de doderlein score", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopiabacilos gram variáveisscore", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura automatizada vaginal", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura com sonicação", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura com sonicação parcial", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura de urina", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("células epiteliais urina", "cultura", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("cultura de urina parcial", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("observação", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("outros urina i", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura para bacilo gram negativo", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura para bacilo gram parcial", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura para bordetella pertussis", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura para trichomonas", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura quantitativa","cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura quantitativa parcial", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram negativos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram positivos", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia bacilos gram variáveis", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia células epiteliais", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia cocobacilos gram negativos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia cocos gram positivos", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia diplococos gram negativos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia eritrócitos", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia leucócitos", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia leveduras", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia material", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura secreção de nasofaringe", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura staphylococcus aureus", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura staphylococcus aureus parcial", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura streptococcus beta hemolítico", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("anaerobios cultura", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("cultura anaerobios parcial", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura parcial", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura urina terceiro jato parcial", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura urina terceiro jato", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("eritrócitos quantitativo urina", "cultura", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("urina cultura 1º jato", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urina cultura jato final", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("urina cultura jato médio", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urina cultura jato", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("bacterioscopia germes coráveis", "cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("dismorfismo urina 1j", "cultura", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("leucócitos quantitativo urina 1j", "cultura", x)}))   

labels <- data.frame(lapply(labels, function(x) {gsub(" kit urg", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" urgência", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" urgente", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" urg", "", x)}))  
 
labels <- data.frame(lapply(labels, function(x) {gsub(" de jejum", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" pós prandial", '', x)})) 
labels <- data.frame(lapply(labels, function(x) {gsub(" pósprandial", '', x)}))                    
labels <- data.frame(lapply(labels, function(x) {gsub(" para coleta domiciliar", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("glicose arterial", "glicose", x)})) 
labels <- data.frame(lapply(labels, function(x) {gsub(" coleta domiciliar", "", x)})) 
labels <- data.frame(lapply(labels, function(x) {gsub("glicemia", "glicose", x)})) 

labels <- data.frame(lapply(labels, function(x) {gsub(" combinada com glicose", '', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("homair", 'insulina', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("insulina/imc índice de massa corporal", 'insulina/insulina', x)}))
  
labels <- data.frame(lapply(labels, function(x) {gsub(" agregacao", '', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq lag time colágeno 10 microgml", 'plaquetas', x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq lag time colágeno 50 microgml", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq máx ác aracdônico 500 microgml", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq máxima adrenalina 20 microm", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq máxima colágeno 10 microgml", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq máxima ristocetina 05ml", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaq máxima ristocetina 12ml", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaquetária máxima adp 100 microm", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("agreg plaquetária máxima adp 25 microm", 'plaquetas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("número de plaquetas no prp após diluição", 'plaquetas', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub(" fracoes", " frações", x)})) #bilirrubinas   
labels <- data.frame(lapply(labels, function(x) {gsub("fracao", "fração", x)})) #bilirrubinas   
labels <- data.frame(lapply(labels, function(x) {gsub("ldh", 'dhll', x)})) #desidrogenase  
labels <- data.frame(lapply(labels, function(x) {gsub("metanefrinas", 'metanefrina', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("citrulinado", 'c', x)})) #peptideo
labels <- data.frame(lapply(labels, function(x) {gsub("urico", 'úrico', x)})) #peptideo

labels <- data.frame(lapply(labels, function(x) {gsub(" soro", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" total e frações", "", x)})) #o exame colesterol total e frações tem analitos difernetes
labels <- data.frame(lapply(labels, function(x) {gsub(" sangue total", "", x)}))         
labels <- data.frame(lapply(labels, function(x) {gsub(" sangue", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" total", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" vários materiais", '', x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub(" contagem", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" especial", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" teste rápido", "", x)})) #dengue
labels <- data.frame(lapply(labels, function(x) {gsub(" livre", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" plasma", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" prova rápida", "", x)})) #creatinina
labels <- data.frame(lapply(labels, function(x) {gsub(" soso", '', x)})) #estradiol  
labels <- data.frame(lapply(labels, function(x) {gsub(" pediátrico", '', x)})) #hormonio luteinizante
labels <- data.frame(lapply(labels, function(x) {gsub(" mg", '', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("magnesio", 'magnésio', x)})) 
labels <- data.frame(lapply(labels, function(x) {gsub(" k", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" por imunoturbidimetria", '', x)})) #proteina c reativa
labels <- data.frame(lapply(labels, function(x) {gsub(" tt", '', x)})) # trombina
labels <- data.frame(lapply(labels, function(x) {gsub(" dr3", "", x)})) #sensibilidade para fungos
labels <- data.frame(lapply(labels, function(x) {gsub(" biodisponível", "", x)})) #testosterona
labels <- data.frame(lapply(labels, function(x) {gsub("triglicerídios tg", 'triglicérides', x)})) #triglicerideos
labels <- data.frame(lapply(labels, function(x) {gsub(" t ultrassensível", '', x)}))  #troponina
labels <- data.frame(lapply(labels, function(x) {gsub(" para hospitais", "", x)})) #protombina   
labels <- data.frame(lapply(labels, function(x) {gsub(" tt", "", x)})) #trombina   
labels <- data.frame(lapply(labels, function(x) {gsub("calcio", 'cálcio', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("catecolaminas", 'catecolamina', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("acido", 'ácido', x)})) #ácido urico
labels <- data.frame(lapply(labels, function(x) {gsub("potassio", 'potássio', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("proteínas", 'proteinas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("e frações", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("t4l", 't4', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" 1j", '', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub(" totais", "", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub(" ptf", "", x)}))      
labels <- data.frame(lapply(labels, function(x) {gsub("proteínas", 'proteinas', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("e frações", '', x)}))
                  
labels <- data.frame(lapply(labels, function(x) {gsub(" após estímulo de tsh", '', x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub(" serica", '', x)}))                      
              
labels <- data.frame(lapply(labels, function(x) {gsub(" reverso", '', x)}))                         
labels <- data.frame(lapply(labels, function(x) {gsub(" tri iodotironina", '', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub(" tetraiodotironina", '', x)}))           

labels <- data.frame(lapply(labels, function(x) {gsub("gasometria arterial", 'gasometria', x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub("gasometria venosa", 'gasometria', x)}))    
                 
labels <- data.frame(lapply(labels, function(x) {gsub("hbht", 'hemograma', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("hemograma automatizado préqt", 'hemograma', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("eritrograma eritrócitos hemoglobina hematócrito", 'hemograma', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("eritrograma", 'hemograma', x)}))                     
labels <- data.frame(lapply(labels, function(x) {gsub("hematócrito", 'hematocrito', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub(" fração hdl", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" fração ldl", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" nãohdl", '', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" fração vldl", '', x)}))
             
labels <- data.frame(lapply(labels, function(x) {gsub(" totais e frações", "", x)}))                     
labels <- data.frame(lapply(labels, function(x) {gsub(" PTF", "", x)}))                          

labels <- data.frame(lapply(labels, function(x) {gsub("urin amostisolada", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("amostra isolada urina", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urinaria", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urinária", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("amostra isolada urina", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urina amostra isolada", 'urinario', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub('urinário', "urinario", x)}))  
labels <- data.frame(lapply(labels, function(x) {gsub('globulinas', "globulina", x)})) 

labels <- data.frame(lapply(labels, function(x) {gsub("\\s+", " ", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" $", "", x)}))
 
labels <- data.frame(lapply(labels, function(x) {gsub("vitamina d 25 hidroxi por lcms", "vitamina d 125 dihidroxi", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("testolms testosterona por lcmsms", "testosterona por lcmsms", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("sódio urina amostra isolada", "sódio urinario", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub(" isolada", "", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("urina tipo 1 jato medio", "urina tipo 1", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urina tipo i 1 jato", "urina tipo 1", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("urina tipo i jato final", "urina tipo 1", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("urina tipo i jato medio", "urina tipo 1", x)}))   

labels <- data.frame(lapply(labels, function(x) {gsub("trichomonas pesquisa secreção uretral", "trichomonas pesquisa", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("trichomonas pesquisa secreção vaginal", "trichomonas pesquisa", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("trichomonas pesquisa urina primeiro jato", "trichomonas pesquisa", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("fungos cultura 1 amostra", "fungos cultura", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("fungos pesquisa 1ª amostra", "fungos cultura", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("transaminase oxalacética tgo", "tgo", x)}))   
labels <- data.frame(lapply(labels, function(x) {gsub("transaminase pirúvica tgp", "tgp", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("micobact ", "micobactérias ", x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("183", "amilase", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cloro arterial", "cloro", x)}))

# %%
tests %>% select(-c(test,analyte)) -> tests
tests %>% cbind(labels) -> tests

tests %>% mutate(test_analyte = (str_c(test, "/", analyte))) -> tests

# %%
tests %>% select(test_analyte) -> labels

# %%
labels <- data.frame(lapply(labels, function(x) {tolower(x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cálcio ionizado/cálcio ionizado pós filtro", 'cálcio ionizado/cálcio ionizado', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cálcio ionizado/cálcio ionizadoarte", 'cálcio ionizado/cálcio ionizado', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cálcio ionizado/cálcio ionizavel", 'cálcio ionizado/cálcio ionizado', x)}))


labels <- data.frame(lapply(labels, function(x) {gsub(" leiden", "", x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("normetnefrina", 'normetanefrina', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("antimitocondrial fração m2 anticorpo", 'antimitocondrial anticorpo', x)}))

tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura fungos", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura/hemocultura fungos parcial", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura/hemocultura para aeróbios", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura/hemocultura para aeróbios parcial", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura para anaeróbios", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura para anaeróbios parcial", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura/hemocultura parcials", 'hemocultura', x)}))
tests <- data.frame(lapply(tests, function(x) {gsub("hemocultura/hemocultura resultado parcial", 'hemocultura', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("testosterona/observação", 'testosterona/testosterona', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("testosterona/shbg", 'testosterona/testosterona', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("testosterona por lcmsms/testosterona massa", 'testosterona por lcmsms/testosterona', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("cultura/resultado integrar com ccih hospitais", 'cultura/cultura', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("cultura/resultado parcial", 'cultura/cultura', x)}))

labels <- data.frame(lapply(labels, function(x) {gsub("prograf em tempos/tacrolimus elisa", 'prograf em tempos/tacrolimus', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("teste de sensibilidade para fungos/resultado integrar com ccih hospitais", 'teste de sensibilidade para fungos/teste de sensibilidade para fungos', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("hemoglobina/hemoglobina", 'hemograma/hemoglobina', x)}))
labels <- data.frame(lapply(labels, function(x) {gsub("hematocrito/hematocrito", 'hemograma/hematocrito', x)}))

# %%
tests %>% select(-c(test_analyte)) -> tests
tests %>% cbind(labels) -> tests
tests %>% write_csv("HSL_Exames_4_labelsproc.csv")
